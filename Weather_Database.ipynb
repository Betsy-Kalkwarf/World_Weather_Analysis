# %%
# Import the dependencies.
import pandas as pd
import gmaps
import requests
import numpy as np
from citipy import citipy

import time
from datetime import datetime

# Import the API key.
from config import g_key

# %%
# 3. Create a set of 2000 latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
#4. Get the nearest city using the citipy module.

#list of cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in lat_lngs:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# %%
#5. Perform an API call with the OpenWeatherMap.
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe0a88e8b9ae859b02326b8fbe775e54

# %%
#6. Retrieve the following information from the API call: Latitude and longitude, Maximum temperature,
    #Percent humidity, Percent cloudiness, Wind speed, Weather description 
    #(for example, clouds, fog, light rain, clear sky)
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_description})

    # If an error is experienced, skip the city.
    except:
        #print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | georgetown
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | conde
# Processing Record 4 of Set 1 | cape town
# Processing Record 5 of Set 1 | gacko
# Processing Record 6 of Set 1 | saint-joseph
# Processing Record 7 of Set 1 | gamba
# Processing Record 8 of Set 1 | busselton
# Processing Record 9 of Set 1 | bjornevatn
# Processing Record 10 of Set 1 | zhob
# Processing Record 11 of Set 1 | hithadhoo
# Processing Record 12 of Set 1 | nizhneyansk
# Processing Record 13 of Set 1 | japura
# Processing Record 14 of Set 1 | barrow
# Processing Record 15 of Set 1 | sharlyk
# Processing Record 16 of Set 1 | sistranda
# Processing Record 17 of Set 1 | amderma
# Processing Record 18 of Set 1 | norman wells
# Processing Record 19 of Set 1 | svetlogorsk
# Processing Record 20 of Set 1 | kapaa
# Processing Record 21 of Set 1 | ribeira grande
# Processing Record 22 of Set 1 | kutum
# ...

# %%
#7. Add the data to a new DataFrame. Before exporting your new DataFrame as a CSV file, 
    #take a moment to confirm that it looks similar to the image below:
cities_df = pd.DataFrame(city_data)
cities_df.head()

#city_df = pd.DataFrame(city_data)
#city_df.head()
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Georgetown      MY   5.4112  100.3354     78.75        91          20
# 1     Ushuaia      AR -54.8000  -68.3000     40.66        75          40
# 2       Conde      BR  -7.2597  -34.9075     76.46        83           0
# 3   Cape Town      ZA -33.9258   18.4232     55.11        73          40
# 4       Gacko      BA  43.1672   18.5353     47.46        95          77
#
#    Wind Speed Current Description
# 0        4.61        thunderstorm
# 1       23.02    scattered clouds
# 2       11.50           clear sky
# 3        8.05    scattered clouds
# 4        5.53       broken clouds

# %%
#8. Export the DataFrame as a CSV file, and save it as WeatherPy_Database.csv in the Weather_Database folder.
cities_df.to_csv("WeatherPy_Database.csv")
